# %% [markdown]
# # **Unemployement Analysis of India during COVID-19 Pandemic**
# The COVID-19 pandemic has had profound effects on global economies, with **unemployment** being one of the most significant impacts. This notebook aims to **analyze the changes in unemployment rates in India during the COVID-19 pandemic**, analyze **regional differences** in unemployment impacts, exploring trends and patterns.<br><br>
# Time Period Covered: July 2019 - November 2020.

# %% [markdown]
# ## **Data Preprocessing**
# The process of detecting and correcting (or removing) corrupt or inaccurate records from a dataset.

# %%
# Importing important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading data
df = pd.read_csv('C:\\Users\\shiwa\\Downloads\\Unemployment in India.csv')
df2 = pd.read_csv('C:\\Users\\shiwa\\Downloads\\Unemployment_Rate_upto_11_2020.csv')

# %%
df.shape
# Out:
# (754, 26)

# %%
df.head()
# Out:
#            Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh  31-05-2019   Monthly                             3.65
# 1  Andhra Pradesh  30-06-2019   Monthly                             3.05
# 2  Andhra Pradesh  31-07-2019   Monthly                             3.75
# 3  Andhra Pradesh  31-08-2019   Monthly                             3.32
# 4  Andhra Pradesh  30-09-2019   Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  \
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  \
# ...

# %%
df2.shape
# Out:
# (267, 26)

# %%
df2.head()
# Out:
#            Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh  31-01-2020         M                             5.48
# 1  Andhra Pradesh  29-02-2020         M                             5.83
# 2  Andhra Pradesh  31-03-2020         M                             5.79
# 3  Andhra Pradesh  30-04-2020         M                            20.51
# 4  Andhra Pradesh  31-05-2020         M                            17.43
#
#    Estimated Employed  Estimated Labour Participation Rate (%) Region.1  \
# 0            16635535                                    41.02    South
# 1            16545652                                    40.90    South
# 2            15881197                                    39.18    South
# 3            11336911                                    33.10    South
# 4            12988845                                    36.46    South
#
#    Longitude  Latitude  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  \
# ...

# %% [markdown]
# ### **Data Reduction**
# Removing unnecessary columns-

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)', 'Area',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
df.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
       'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
       'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
       'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
       'Unnamed: 24', 'Unnamed: 25', 'Area', 'Frequency'], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Region.1', 'Longitude', 'Latitude', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
df2.drop(['Longitude', 'Region.1', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
       'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
       'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
       'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
       'Unnamed: 24', 'Unnamed: 25', 'Latitude', 'Frequency'], axis = 1, inplace = True)

# %%
df2.columns
# Out:
# Index(['Region', 'Date', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)'],
#       dtype='object')

# %% [markdown]
# ### **Data Transformation**
# Converting data types for better analysis and concating two different dataframes.

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
df2['Date'] = pd.to_datetime(df2['Date'], dayfirst=True)
data = pd.concat([df, df2], ignore_index=True)
data
# Out:
#               Region       Date  Estimated Unemployment Rate (%)  \
# 0     Andhra Pradesh 2019-05-31                             3.65
# 1     Andhra Pradesh 2019-06-30                             3.05
# 2     Andhra Pradesh 2019-07-31                             3.75
# 3     Andhra Pradesh 2019-08-31                             3.32
# 4     Andhra Pradesh 2019-09-30                             5.17
# ...              ...        ...                              ...
# 1016     West Bengal 2020-06-30                             7.29
# 1017     West Bengal 2020-07-31                             6.83
# 1018     West Bengal 2020-08-31                            14.87
# 1019     West Bengal 2020-09-30                             9.35
# 1020     West Bengal 2020-10-31                             9.98
#
#       Estimated Employed  Estimated Labour Participation Rate (%)
# 0             11999139.0                                    43.24
# ...

# %% [markdown]
# ### **Data Cleaning**
# Identifying null and duplicated values and removing them.

# %%
data.isnull().sum()
# Out:
# Region                                     14
# Date                                       14
# Estimated Unemployment Rate (%)            14
# Estimated Employed                         14
# Estimated Labour Participation Rate (%)    14
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 70

# %%
data['Date'] = data['Date'].ffill()
data['Date'].isnull().sum()
# Out:
# 0

# %%
data = data.fillna(0)
data.isnull().sum().sum()
# Out:
# 0

# %%
data.duplicated().sum()
# Out:
# 13

# %%
data.drop_duplicates(inplace = True)
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (1008, 5)

# %%
data.describe()
# Out:
#                                 Date  Estimated Unemployment Rate (%)  \
# count                           1008                      1008.000000
# mean   2020-01-31 09:41:25.714285568                        11.895179
# min              2019-05-31 00:00:00                         0.000000
# 25%              2019-09-30 00:00:00                         4.677500
# 50%              2020-01-31 00:00:00                         8.880000
# 75%              2020-05-31 00:00:00                        16.117500
# max              2020-10-31 00:00:00                        76.740000
# std                              NaN                        10.740764
#
#        Estimated Employed  Estimated Labour Participation Rate (%)
# count        1.008000e+03                              1008.000000
# mean         8.987284e+06                                42.336577
# min          0.000000e+00                                 0.000000
# 25%          1.629544e+06                                37.827500
# ...

# %% [markdown]
# ## **Data Visualization**
# ### **Unemployment Trends Line Plot**

# %%
data.columns
# Out:
# Index(['Region', 'Date', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)'],
#       dtype='object')

# %%
# Plotting lineplot of unemployment rate of India
sns.set_style('dark')
plt.figure(figsize = (14,6))
sns.lineplot(data=data, x="Date", y="Estimated Unemployment Rate (%)")
plt.title('Unemployment Rate of INDIA')
plt.grid(True)
plt.show()

# %% [markdown]
# **Observation-** <br>
# * **March 2020**: Beginning of the lockdown, causing initial disruptions in employment.
# * **April 2020 - June 2020**: Peak of the lockdown, with most sectors, especially non-essential services, facing significant layoffs.
# * **June 2020**: Gradual easing of lockdown restrictions, allowing some sectors to resume operations. Marked by gradual reopening and adaptation to new health guidelines, leading to a decline in unemployment rates.
# * **August 2020 and Beyond**: Continued easing of restrictions and adaptation to remote work contributed to the stabilization of unemployment rates.<br>

# %%
# Comparision between rural and urban unemployment
ur = pd.read_csv('C:\\Users\\shiwa\\Downloads\\Unemployment in India.csv')
ur['Area'] = ur['Area'].ffill()
sns.set_style('dark')
plt.figure(figsize = (14,6))
sns.lineplot(data=ur, x="Date", y="Estimated Unemployment Rate (%)", hue = 'Area')
plt.title('Unemployment Rate of Rural and Urban INDIA')
plt.grid(True)
plt.show()

# %% [markdown]
# **Observation-** <br>
# * **Urban Areas**: Significant spike during lockdown; indicates greater impact of pandemic restrictions. Urban areas depend more on services and industries heavily impacted by the pandemic. Higher density in urban areas led to stricter lockdown measures and greater economic disruptions.
# * **Rural Areas**: Indicates relative resilience due to the continuation of agricultural and informal sector activities. Smaller increase; shows relative stability and resilience. Rural areas, with more diversified and informal employment, exhibited greater resilience during the pandemic.

# %%
# Plotting lineplot of unemployment rate of North India
plt.figure(figsize = (14,6))
north = data.query("Region == ['Rajasthan', 'Delhi', 'Haryana', 'Jammu & Kashmir', 'Himachal Pradesh', 'Punjab', 'Uttar Pradesh', 'Uttarakhand']")
sns.lineplot(data = north, x="Date", y="Estimated Unemployment Rate (%)", hue = 'Region')
plt.title('Unemployment Rate of NORTH INDIA')
plt.grid(True)
plt.show()

# %%
# Plotting lineplot of unemployment rate of Northeast India
plt.figure(figsize = (14,6))
northeast = data.query("Region == ['Assam', 'Meghalaya', 'Sikkim', 'Tripura']")
sns.lineplot(data = northeast, x="Date", y="Estimated Unemployment Rate (%)", hue = 'Region')
plt.title('Unemployment Rate of NORTHEAST INDIA')
plt.grid(True)
plt.show()

# %%
# Plotting lineplot of unemployment rate of South India
plt.figure(figsize = (14,6))
south = data.query("Region == ['Andhra Pradesh', 'Kerala', 'Karnataka', 'Telangana', 'Tamil Nadu', 'Puducherry']")
sns.lineplot(data=south, x="Date", y="Estimated Unemployment Rate (%)", hue = 'Region')
plt.title('Unemployment Rate of SOUTH INDIA')
plt.grid(True)
plt.show()

# %%
# Plotting lineplot of unemployment rate of West India
plt.figure(figsize = (14,6))
west = data.query("Region == ['Goa', 'Gujarat', 'Madhya Pradesh', 'Maharashtra', 'Chhattisgarh']")
sns.lineplot(data = west, x="Date", y="Estimated Unemployment Rate (%)", hue = 'Region')
plt.title('Unemployment Rate of WEST INDIA')
plt.grid(True)
plt.show()

# %%
# Plotting lineplot of unemployment rate of East India
plt.figure(figsize = (14,6))
east = data.query("Region == ['Bihar', 'Jharkhand', 'West Bengal', 'Odisha']")
sns.lineplot(data = east, x="Date", y="Estimated Unemployment Rate (%)", hue = 'Region')
plt.title('Unemployment Rate of EAST INDIA')
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Employed Trends Line Plot**

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data = data, x="Date", y="Estimated Employed")
plt.title('Estimated Employed in INDIA')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data = north, x="Date", y="Estimated Employed", hue = 'Region')
plt.title('Estimated Employed in NORTH INDIA')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data = northeast, x="Date", y="Estimated Employed", hue = 'Region')
plt.title('Estimated Employed in NORTHEAST INDIA')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data = south, x="Date", y="Estimated Employed", hue = 'Region')
plt.title('Estimated Employed in SOUTH INDIA')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data = west, x="Date", y="Estimated Employed", hue = 'Region')
plt.title('Estimated Employed in WEST INDIA')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data = east, x="Date", y="Estimated Employed", hue = 'Region')
plt.title('Estimated Employed in EAST INDIA')
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Labour Participation Trends Line Plot**

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data=data, x="Date", y="Estimated Labour Participation Rate (%)")
plt.title('Labour Participation Rate of INDIA')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data=north, x="Date", y="Estimated Labour Participation Rate (%)", hue = 'Region')
plt.title('Labour Participation Rate of NORTH INDIA')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data=northeast, x="Date", y="Estimated Labour Participation Rate (%)", hue = 'Region')
plt.title('Labour Participation Rate of NORTHEAST INDIA')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data=south, x="Date", y="Estimated Labour Participation Rate (%)", hue = 'Region')
plt.title('Labour Participation Rate of SOUTH INDIA')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data = west, x="Date", y="Estimated Labour Participation Rate (%)", hue = 'Region')
plt.title('Labour Participation Rate of WEST INDIA')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data = east, x="Date", y="Estimated Labour Participation Rate (%)", hue = 'Region')
plt.title('Labour Participation Rate of EAST INDIA')
plt.grid(True)
plt.show()
